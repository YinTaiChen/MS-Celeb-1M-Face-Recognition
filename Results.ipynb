# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt

# %%
font = {'family' : 'sans-serif',
 'weight' : 'bold',
 'size' : 20}
matplotlib.rc('font', **font)

# %%
train_acc = [
    0.0181, 
    0.1310, 
    0.3245, 
    0.4705, 
    0.5625, 
    0.6222, 
    0.7235, 
    0.7395, 
    0.7456, 
    0.7510, 
    0.7555, 
    0.7593, 
    0.7634, 
    0.7711, 
    0.7735, 
    0.7746, 
    0.7751, 
    0.7757, 
    0.7764, 
    0.7770, 
    0.7779, 
    0.7775, 
    0.7781, 
    0.7781, 
    0.7782
]

# %%
test_acc = [
    0.0596,
    0.2478,
    0.4294,
    0.5273,
    0.5927,
    0.6316,
    0.7067,
    0.7117,
    0.7147,
    0.7081,
    0.7176,
    0.7305,
    0.7315,
    0.7320,
    0.7356,
    0.7317,
    0.7372,
    0.7396,
    0.7404,
    0.7386,
    0.7303,
    0.7362,
    0.7377,
    0.7396,
    0.7362
]

# %%
axes = plt.gca()
axes.set_ylim([0.0,100.0])
axes.set_xlabel('Epoch')
axes.set_ylabel('Accuracy(%)')

fig = plt.gcf()
fig.set_size_inches(18.5, 10.5)

x = [i for i in range(1, 26)]
y_train = [acc*100 for acc in train_acc]
y_test = [acc*100 for acc in test_acc]

plt.plot(x, y_train, '--o', label="training")
plt.plot(x, y_test, '--o', label="testing")
plt.legend(loc='upper left')
plt.savefig('Accuracy.png', format='png')

# %%
train_loss = [
    2.0536,
    1.5168,
    1.0649,
    0.8010,
    0.6492,
    0.5554,
    0.4096,
    0.3865,
    0.3758,
    0.3670,
    0.3602,
    0.3541,
    0.3477,
    0.3364,
    0.3331,
    0.3318,
    0.3310,
    0.3299,
    0.3287,
    0.3283,
    0.3268,
    0.3272,
    0.3262,
    0.3262,
    0.3258,
]

# %%
test_loss = [
    1.7424,
    1.2277,
    0.8792,
    0.7130,
    0.6101,
    0.5508,
    0.4414,
    0.4332,
    0.4292,
    0.4423,
    0.4257,
    0.4027,
    0.4012,
    0.4013,
    0.3972,
    0.4033,
    0.3931,
    0.3899,
    0.3892,
    0.3918,
    0.4069,
    0.3956,
    0.3918,
    0.3899,
    0.3950
]

# %%
axes = plt.gca()
axes.set_ylim([0.0, 2.5])
axes.set_xlabel('Epoch')
axes.set_ylabel('Cross Entropy Loss')

fig = plt.gcf()
fig.set_size_inches(18.5, 10.5)

x = [i for i in range(1, 26)]

plt.plot(x, train_loss, '--o', label="training")
plt.plot(x, test_loss, '--o', label="testing")
plt.legend(loc='upper left')
plt.savefig('Loss.png', format='png')
